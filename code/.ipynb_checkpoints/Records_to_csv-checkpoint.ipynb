# %%
import numpy as np
import pandas as pd
import os 
import json

pd.options.display.max_rows = 999

# %% [markdown]
# - tab_4, 5, 6, 6 --> Lukas & Sascha
# - tab_1, 2, 3 --> leer

# %%
paths = ["../data/" + file + "/" for file in os.listdir("../data")]
paths
# Out:
# ['../data/.DS_Store/',
#  '../data/tub_11_20-08-25/',
#  '../data/tub_6_20-08-19/',
#  '../data/tub_7_20-08-19/',
#  '../data/tub_12_20-08-25-raus-gesetzt/',
#  '../data/backup/',
#  '../data/tub_5_20-08-18/',
#  '../data/tub_4_20-08-18/',
#  '../data/tub_13_20-08-25/']

# %%
DIR = "tub_4_20-08-18"

# %%
path = "../data/" + DIR + "/"
filenumbers = np.sort([file.replace("record_", "").replace(".json", "") for file in os.listdir(path) if file.endswith(".json")])
filenumbers = np.sort([int(filenumber) for filenumber in filenumbers if filenumber != "meta"])[::-1]

# %%
df = pd.read_csv(f"records_{DIR}.csv")

# %%
# %%time
df = pd.DataFrame()
for i in filenumbers: 
    with open(path + f"record_{i}.json", "r") as file: 
        f = file.read()
        d = eval(f)
        df_ = pd.DataFrame(d, index=[i])
        df = pd.concat([df_, df], sort=True)
# Out:
# CPU times: user 11.6 s, sys: 383 ms, total: 12 s
# Wall time: 12.7 s

# %%
df.head()
# Out:
#                 cam/image_array  milliseconds    user/angle user/mode  \
# 1635  1635_cam-image_array_.jpg       1165483 -2.775558e-17      user
# 1636  1636_cam-image_array_.jpg       1165533 -2.775558e-17      user
# 1637  1637_cam-image_array_.jpg       1165586 -2.775558e-17      user
# 1638  1638_cam-image_array_.jpg       1165634 -2.775558e-17      user
# 1639  1639_cam-image_array_.jpg       1165686 -2.775558e-17      user
#
#       user/throttle
# 1635   1.387779e-17
# 1636   1.387779e-17
# 1637   1.387779e-17
# 1638   1.387779e-17
# 1639   1.387779e-17

# %%
print(len(df[df["user/throttle"] <= 0.1]))
df[df["user/throttle"] <= 0.1]
# Out:
# 67
#                 cam/image_array  milliseconds    user/angle user/mode  \
# 1635  1635_cam-image_array_.jpg       1165483 -2.775558e-17      user
# 1636  1636_cam-image_array_.jpg       1165533 -2.775558e-17      user
# 1637  1637_cam-image_array_.jpg       1165586 -2.775558e-17      user
# 1638  1638_cam-image_array_.jpg       1165634 -2.775558e-17      user
# 1639  1639_cam-image_array_.jpg       1165686 -2.775558e-17      user
# 1640  1640_cam-image_array_.jpg       1165739 -2.775558e-17      user
# 1641  1641_cam-image_array_.jpg       1165786 -2.775558e-17      user
# 1642  1642_cam-image_array_.jpg       1165837 -2.775558e-17      user
# 1643  1643_cam-image_array_.jpg       1165886 -2.775558e-17      user
# 1644  1644_cam-image_array_.jpg       1165940 -2.775558e-17      user
# 1645  1645_cam-image_array_.jpg       1165986 -2.775558e-17      user
# 1646  1646_cam-image_array_.jpg       1166043 -2.775558e-17      user
# 1647  1647_cam-image_array_.jpg       1166091 -2.775558e-17      user
# 1648  1648_cam-image_array_.jpg       1166138 -2.775558e-17      user
# 1649  1649_cam-image_array_.jpg       1166192 -2.775558e-17      user
# 1650  1650_cam-image_array_.jpg       1166240 -2.775558e-17      user
# 1651  1651_cam-image_array_.jpg       1166294 -2.775558e-17      user
# 1652  1652_cam-image_array_.jpg       1166344 -2.775558e-17      user
# 1653  1653_cam-image_array_.jpg       1166393 -2.775558e-17      user
# 1654  1654_cam-image_array_.jpg       1166444 -2.775558e-17      user
# 1655  1655_cam-image_array_.jpg       1166494 -2.775558e-17      user
# 1656  1656_cam-image_array_.jpg       1166547 -2.775558e-17      user
# 5178  5178_cam-image_array_.jpg       1344463 -1.000000e-01      user
# 5179  5179_cam-image_array_.jpg       1344516 -1.000000e-01      user
# 5180  5180_cam-image_array_.jpg       1344564 -1.000000e-01      user
# 5181  5181_cam-image_array_.jpg       1344616 -1.000000e-01      user
# 5182  5182_cam-image_array_.jpg       1344664 -1.000000e-01      user
# 5183  5183_cam-image_array_.jpg       1344717 -1.000000e-01      user
# 5184  5184_cam-image_array_.jpg       1344765 -1.000000e-01      user
# 5185  5185_cam-image_array_.jpg       1344817 -1.000000e-01      user
# 5186  5186_cam-image_array_.jpg       1344869 -1.000000e-01      user
# 5187  5187_cam-image_array_.jpg       1344916 -1.000000e-01      user
# 5188  5188_cam-image_array_.jpg       1344970 -1.000000e-01      user
# 5189  5189_cam-image_array_.jpg       1345017 -1.000000e-01      user
# 5190  5190_cam-image_array_.jpg       1345070 -1.000000e-01      user
# 5191  5191_cam-image_array_.jpg       1345122 -1.000000e-01      user
# 5192  5192_cam-image_array_.jpg       1345169 -1.000000e-01      user
# 5193  5193_cam-image_array_.jpg       1345222 -1.000000e-01      user
# 5194  5194_cam-image_array_.jpg       1345274 -1.000000e-01      user
# 5195  5195_cam-image_array_.jpg       1345322 -1.000000e-01      user
# 5196  5196_cam-image_array_.jpg       1345375 -1.000000e-01      user
# 5197  5197_cam-image_array_.jpg       1345422 -1.000000e-01      user
# 5198  5198_cam-image_array_.jpg       1345474 -2.775558e-17      user
# 5199  5199_cam-image_array_.jpg       1345526 -2.775558e-17      user
# 5200  5200_cam-image_array_.jpg       1345574 -2.775558e-17      user
# 5201  5201_cam-image_array_.jpg       1345627 -2.775558e-17      user
# 5202  5202_cam-image_array_.jpg       1345678 -2.775558e-17      user
# 5203  5203_cam-image_array_.jpg       1345726 -2.775558e-17      user
# 5204  5204_cam-image_array_.jpg       1345779 -2.775558e-17      user
# 5205  5205_cam-image_array_.jpg       1345827 -2.775558e-17      user
# 5206  5206_cam-image_array_.jpg       1345877 -2.775558e-17      user
# 5207  5207_cam-image_array_.jpg       1345928 -2.775558e-17      user
# 5208  5208_cam-image_array_.jpg       1345977 -2.775558e-17      user
# 5209  5209_cam-image_array_.jpg       1346029 -2.775558e-17      user
# 5210  5210_cam-image_array_.jpg       1346079 -2.775558e-17      user
# 5211  5211_cam-image_array_.jpg       1346133 -2.775558e-17      user
# 5212  5212_cam-image_array_.jpg       1346184 -2.775558e-17      user
# 5213  5213_cam-image_array_.jpg       1346231 -2.775558e-17      user
# 5214  5214_cam-image_array_.jpg       1346285 -2.775558e-17      user
# 5215  5215_cam-image_array_.jpg       1346337 -2.775558e-17      user
# 5216  5216_cam-image_array_.jpg       1346385 -2.775558e-17      user
# 5217  5217_cam-image_array_.jpg       1346438 -2.775558e-17      user
# 5218  5218_cam-image_array_.jpg       1346491 -2.775558e-17      user
# 5219  5219_cam-image_array_.jpg       1346576 -2.775558e-17      user
# 5220  5220_cam-image_array_.jpg       1346592 -2.775558e-17      user
# 5221  5221_cam-image_array_.jpg       1346641 -2.775558e-17      user
# 5222  5222_cam-image_array_.jpg       1346692 -2.775558e-17      user
#
#       user/throttle
# 1635   1.387779e-17
# 1636   1.387779e-17
# 1637   1.387779e-17
# 1638   1.387779e-17
# 1639   1.387779e-17
# 1640   1.387779e-17
# 1641   1.387779e-17
# 1642   1.387779e-17
# 1643   1.387779e-17
# 1644   1.387779e-17
# 1645   1.387779e-17
# 1646   1.387779e-17
# 1647   5.000000e-02
# 1648   5.000000e-02
# 1649   5.000000e-02
# 1650   5.000000e-02
# 1651   5.000000e-02
# 1652   5.000000e-02
# 1653   5.000000e-02
# 1654   5.000000e-02
# 1655   5.000000e-02
# 1656   5.000000e-02
# 5178   5.000000e-02
# 5179   5.000000e-02
# 5180   5.000000e-02
# 5181   5.000000e-02
# 5182   5.000000e-02
# 5183   5.000000e-02
# 5184   5.000000e-02
# 5185   5.000000e-02
# 5186   5.000000e-02
# 5187   5.000000e-02
# 5188   5.000000e-02
# 5189   5.000000e-02
# 5190   5.000000e-02
# 5191   1.387779e-17
# 5192   1.387779e-17
# 5193   1.387779e-17
# 5194   1.387779e-17
# 5195   1.387779e-17
# 5196   1.387779e-17
# 5197   1.387779e-17
# 5198   1.387779e-17
# 5199   1.387779e-17
# 5200   1.387779e-17
# 5201   1.387779e-17
# 5202   1.387779e-17
# 5203   1.387779e-17
# 5204   1.387779e-17
# 5205   1.387779e-17
# 5206   1.387779e-17
# 5207   1.387779e-17
# 5208   1.387779e-17
# 5209   1.387779e-17
# 5210   1.387779e-17
# 5211   1.387779e-17
# 5212   1.387779e-17
# 5213   1.387779e-17
# 5214   1.387779e-17
# 5215   1.387779e-17
# 5216   1.387779e-17
# 5217   1.387779e-17
# 5218   1.387779e-17
# 5219   1.387779e-17
# 5220   1.387779e-17
# 5221   1.387779e-17
# 5222   1.387779e-17

# %%
print(f'records_{DIR}.csv')
df.to_csv(f'records_{DIR}.csv')
# Out:
# records_tub_4_20-08-18.csv

# %% [markdown]
# tub_5_20-08-18.csv:  67 Datenpunkte ohne Bewegung (<0.1) <br>
# tub_5_20-08-18.csv:  62 Datenpunkte ohne Bewegung (<0.1) <br>
# tub_6_20-08-19.csv:  34 Datenpunkte ohne Bewegung (<0.1) <br>
# tub_7_20-08-19.csv:  16 Datenpunkte ohne Bewegung (<0.1) <br>
# tub_11_20-08-25.csv: 0 Datenpunkte ohne Bewegung (<0.1) <br>
# tub_12_20-08-25-raus-gesetzt.csv: 0 Datenpunkte ohne Bewegung (<0.1) <br>
# tub_13_20-08-25: 314 Datenpunkte ohne Bewegung (<0.1)

# %%
os.listdir(".")
# Out:
# ['Untitled.ipynb', '.ipynb_checkpoints', 'records_tub_11_20-08-25.csv']

# %%
# Out:
# Empty DataFrame
# Columns: [cam/image_array, milliseconds, user/angle, user/mode, user/throttle]
# Index: []

# %%
d["index"] = d['cam/image_array']

# %%
d
# Out:
# {'cam/image_array': '5315_cam-image_array_.jpg',
#  'user/angle': -0.10000000000000003,
#  'user/throttle': 0.25,
#  'user/mode': 'user',
#  'milliseconds': 463309,
#  'index': '5315_cam-image_array_.jpg'}

# %%
df1 = pd.DataFrame(d, index=[i])

# %%
df2 =  pd.DataFrame(d, index=[i])

# %%
pd.concat

# %%
f
# Out:
# '{"cam/image_array": "1_cam-image_array_.jpg", "user/angle": -0.20000000000000004, "user/throttle": 0.25, "user/mode": "user", "milliseconds": 195114}'

# %%
int(f)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-15c82ade717a> in <module>
# ----> 1 int(f)
#
# ValueError: invalid literal for int() with base 10: '{"cam/image_array": "1_cam-image_array_.jpg", "user/angle": -0.20000000000000004, "user/throttle": 0.25, "user/mode": "user", "milliseconds": 195114}'

# %%
import pandas as pd
pd.read_json(path + "record_1.json", orient="records")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-a6d5b2756989> in <module>
#       1 import pandas as pd
# ----> 2 pd.read_json(path + "record_1.json", orient="records")
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
#     610         filepath_or_buffer.close()
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/pandas/io/json/_json.py in read(self)
#     729             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     730         else:
# --> 731             obj = self._get_object_parser(self.data)
#     732         self.close()
#     733         return obj
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     751         obj = None
#     752         if typ == "frame":
# --> 753             obj = FrameParser(json, **kwargs).parse()
#     754
#     755         if typ == "series" or obj is None:
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/pandas/io/json/_json.py in parse(self)
#     855
#     856         else:
# --> 857             self._parse_no_numpy()
#     858
#     859         if self.obj is None:
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1106         else:
#    1107             self.obj = DataFrame(
# -> 1108                 loads(json, precise_float=self.precise_float), dtype=None
#    1109             )
#    1110
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     353
#     354         if not indexes and not raw_lengths:
# --> 355             raise ValueError("If using all scalar values, you must pass an index")
#     356
#     357         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
json.load(path + "record_1.json")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-1bfc4231411b> in <module>
# ----> 1 json.load(path + "record_1.json")
#
# ~/miniconda3/envs/fastai/lib/python3.7/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# AttributeError: 'str' object has no attribute 'read'

# %%
path
# Out:
# '../data/tub_11_20-08-25/'
